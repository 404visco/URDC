# %%
'''
SYARAT
--> Untuk width = 5, nilai hasil smoothing pada indeks n adalah
    rata-rata dari x[n-2], x[n-1], x[n], x[n+1], x[n+2]
--> Secara umum: smoothed[n] = mean(x[n-k : n+k+1]) dimana k = (width-1)//2
--> Jika width genap, TIDAK ubah menjadi ganjil
--> Gunakan asymmetric window yang condong ke depan. Contoh:
    untuk width = 4, gunakan window [n-1, n, n+1, n+2]
--> Untuk posisi di dekat awal/akhir array, gunakan window yang
    tersedia. Contoh: untuk width = 5 di n = 0,
    gunakan mean(x[0:3])
--> Pastikan panjang output sama dengan input
--> Data yang digunakan:
    a. Generate x = 200 titik merata dari 0 sampai 100
    b. Hitung f(x) = x2
    c. Tambahkan noise: y_noisy = x2 + randn
    d. Gunakan np.random.seed(42) untuk hasil yang reproducible
--> Output yang diharapkan:
    a. Titik-titik data noisy (scatter plot)
    b. Garis fungsi asli f(x) = x2
    c. Garis hasil smoothing dengan beberapa window size (contoh:
    3, 5, 7, 10)
    d. Legenda, judul, dan label sumbu
'''
# Out:
# '\nSYARAT\n--> Untuk width = 5, nilai hasil smoothing pada indeks n adalah\n    rata-rata dari x[n-2], x[n-1], x[n], x[n+1], x[n+2]\n--> Secara umum: smoothed[n] = mean(x[n-k : n+k+1]) dimana k = (width-1)//2\n--> Jika width genap, TIDAK ubah menjadi ganjil\n--> Gunakan asymmetric window yang condong ke depan. Contoh:\n    untuk width = 4, gunakan window [n-1, n, n+1, n+2]\n--> Untuk posisi di dekat awal/akhir array, gunakan window yang\n    tersedia. Contoh: untuk width = 5 di n = 0,\n    gunakan mean(x[0:3])\n--> Pastikan panjang output sama dengan input\n--> Data yang digunakan:\n    a. Generate x = 200 titik merata dari 0 sampai 100\n    b. Hitung f(x) = x2\n    c. Tambahkan noise: y_noisy = x2 + randn\n    d. Gunakan np.random.seed(42) untuk hasil yang reproducible\n--> Output yang diharapkan:\n    a. Titik-titik data noisy (scatter plot)\n    b. Garis fungsi asli f(x) = x2\n    c. Garis hasil smoothing dengan beberapa window size (contoh:\n    3, 5, 7, 10)\n    d. Legenda, judul, dan label sumbu\n'

# %%
#Setup
import numpy as np
import matplotlib.pyplot as plt

# %%
#buat x dan noise
np.random.seed(42) #biar producable
x = np.linspace(0,100,200) #200 titik, nilai merata 0-100
noise = np.random.randn(len(x))*500 #biar terlihat

# %%
#Buat fungsi y_asli dan y_noisy
y= x*x
y_noise = y + noise

# %%
def moving_average_filter(data, width):
    panjang = len(data)
    list_y_new = []
    for i in range(panjang):
        if width%2 == 1: #--> Ganjil
            k = (width-1)//2
            start = max(i-k,0)
            end = min(i+k+1, panjang)
        else: #--> Genap
            k= width//2 
            start= max(i-k-1,0) #condong depan
            end= min(i+k,panjang)
        y_new = np.mean(y_noise[start:end]) #smoothed
        list_y_new.append(y_new)
    return list_y_new

# %%
plt.figure(figsize=(10,6))
#Titik data noisy
plt.scatter(x, y_noise, s=15, alpha=0.6, label= 'Titik data noisy')
#Garis fungsi asli f(x) = x2
plt.plot(x,y, color= 'black',linewidth=2, label= 'Fungsi Asli f(x) = x^2')
#Garis hasil smoothing dengan beberapa window size (contoh: 3, 5, 7, 10)
window= [4,9,14,19]
color = ['red', 'blue', 'orange', 'green']
for i,j in zip(window,color):
    plt.plot(x,moving_average_filter(x, i),color = j, linewidth= 2, label= f'Garis hasil smoothing (width= {i})')



#Legenda, judul, dan label sumbu
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Moving Average Filter')
# Out:
# Text(0.5, 1.0, 'Moving Average Filter')

# %%
#width 4
plt.scatter(x, y_noise, s=15, alpha=0.6, label= 'Titik data noisy')
plt.plot(x,moving_average_filter(x, 4),color = 'red', linewidth= 2, label= f'Garis hasil smoothing (width= {i})')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Moving Average Filter')
# Out:
# Text(0.5, 1.0, 'Moving Average Filter')

# %%
#width 9
plt.scatter(x, y_noise, s=15, alpha=0.6, label= 'Titik data noisy')
plt.plot(x,moving_average_filter(x, 9),color = 'blue', linewidth= 2, label= f'Garis hasil smoothing (width= {i})')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Moving Average Filter')
# Out:
# Text(0.5, 1.0, 'Moving Average Filter')

# %%
#width 14
plt.scatter(x, y_noise, s=15, alpha=0.6, label= 'Titik data noisy')
plt.plot(x,moving_average_filter(x, 14),color = 'orange', linewidth= 2, label= f'Garis hasil smoothing (width= {i})')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Moving Average Filter')
# Out:
# Text(0.5, 1.0, 'Moving Average Filter')

# %%
#wisth 19
plt.scatter(x, y_noise, s=15, alpha=0.6, label= 'Titik data noisy')
plt.plot(x,moving_average_filter(x, 14),color = 'green', linewidth= 2, label= f'Garis hasil smoothing (width= {i})')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Moving Average Filter')
# Out:
# Text(0.5, 1.0, 'Moving Average Filter')
